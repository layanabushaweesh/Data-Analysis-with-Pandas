# %% [markdown]
# ## using panda for data analaysis

# %%
import pandas as pd
import numpy as np

# %%
# read cv file
df = pd.read_csv('./vgsales.csv')

# %%
pd
# Out:
# <module 'pandas' from '/mnt/c/Users/hp/Data-Analysis-with-Pandas/vg-stats/.venv/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## q1 Which company is the most common video game publisher?

# %%
most_common=df[["Publisher"]].mode()
most_common
# Out:
#          Publisher
# 0  Electronic Arts

# %% [markdown]
# ## q2 What’s the most common platform?

# %%
most_common_2=df[["Platform"]].mode()
most_common_2
# Out:
#   Platform
# 0       DS

# %% [markdown]
# ## q3 What about the most common genre?

# %%
most_common_3=df[['Genre']].mode()
most_common_3
# Out:
#     Genre
# 0  Action

# %% [markdown]
# ## q4 What are the top 20 highest grossing games?

# %%
data_by_nameandglobalsale=df.groupby(['Name','Global_Sales'])
data_by_nameandglobalsale.describe()
# Out:
#                                                       Rank               \
#                                                      count     mean std
# Name                                    Global_Sales
# '98 Koshien                             0.41           1.0   4756.0 NaN
# .hack//G.U. Vol.1//Rebirth              0.17           1.0   8359.0 NaN
# .hack//G.U. Vol.2//Reminisce            0.23           1.0   7109.0 NaN
# .hack//G.U. Vol.2//Reminisce (jp sales) 0.16           1.0   8604.0 NaN
# .hack//G.U. Vol.3//Redemption           0.17           1.0   8306.0 NaN
# ...                                                    ...      ...  ..
# uDraw Studio                            2.46           1.0    628.0 NaN
# uDraw Studio: Instant Artist            0.02           1.0  15526.0 NaN
#                                         0.19           1.0   7837.0 NaN
# wwe Smackdown vs. Raw 2006              3.00           1.0    471.0 NaN
# ...

# %%
data_by_nameandglobalsale.head(20)
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
top_20=data_by_nameandglobalsale.head(20).sort_values('Global_Sales', ascending=False).head(20)
top_20
####the final answer for q4 here####
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ## q5 For North American video game sales, what’s the median?

# %%
the_median = df[['NA_Sales']].median()[0]

print(f'the median is => {the_median}')
# Provide a secondary output showing ten games surrounding the median sales output
median_ten_game = df[df["NA_Sales"] == the_median][["Name"]].head(10)
print(median_ten_game)
# assume that games with same median value are sorted in descending order
# Out:
# the median is => 0.08
#                                                    Name
# 446                                   Dragon Warrior IV
# 497         World Soccer Winning Eleven 7 International
# 1617                             Farming Simulator 2015
# 1926                          Pro Evolution Soccer 2008
# 2067  Winning Eleven: Pro Evolution Soccer 2007 (All...
# 2373                           Phantasy Star Portable 2
# 2579                               The Sims 2: Castaway
# 3186                                     SingStar Queen
# 3503                                         Top Spin 3
# 3703               Sonic & All-Stars Racing Transformed

# %% [markdown]
# ## q6 For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
standard_deviations=df['NA_Sales'].std()
# print(standard_deviations)
the_mean=df['NA_Sales'].mean()
top_seling=df["NA_Sales"].iloc[0]
the_result=(-the_mean+top_seling)/standard_deviations
print(the_result)
# Out:
# 50.47898767479108

# %% [markdown]
# ## q7 The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
The_Nintendo_Wii=df[df['Platform']=="Wii"].mean()
print(The_Nintendo_Wii.Global_Sales.mean())
# Out:
# 0.6994037735849057

# %% [markdown]
# ## q8 Come up with 3 more questions that can be answered with this data set.

# %%
#q1 the What about the most common NAME?
most_common_4=df[['Name']].mode()
most_common_4
# Out:
#                           Name
# 0  Need for Speed: Most Wanted

# %%
#q2  What is standard devision for jp sales ?

standard_deviation = df[['JP_Sales']].std()[0]
standard_deviation
# Out:
# 0.30929064808220297

# %%
#q3 give us the data for  fifa 14 game?
fifa_data = df[ df['Name']=='FIFA 14' ]
fifa_data
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 112    113  FIFA 14      PS3  2013.0  Sports  Electronic Arts      0.78
# 256    257  FIFA 14     X360  2013.0  Sports  Electronic Arts      0.92
# 493    494  FIFA 14      PS4  2013.0  Sports  Electronic Arts      0.61
# 1698  1700  FIFA 14     XOne  2013.0  Sports  Electronic Arts      0.41
# 3988  3990  FIFA 14      PSV  2013.0  Sports  Electronic Arts      0.11
# 4503  4505  FIFA 14       PC  2013.0  Sports  Electronic Arts      0.01
# 4538  4540  FIFA 14      Wii  2013.0  Sports  Electronic Arts      0.00
# 6661  6663  FIFA 14      3DS  2013.0  Sports  Electronic Arts      0.00
# 7034  7036  FIFA 14      PSP  2013.0  Sports  Electronic Arts      0.00
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 112       4.32      0.07         1.73          6.90
# 256       2.93      0.01         0.46          4.31
# 493       1.85      0.11         0.33          2.90
# ...

# %%
def test():

    def assert_equal(actual,expected):
        
        assert actual == expected, f"Expected {expected} but got {actual}"
        
        assert_equal(most_common_platform, "DS")
        assert_equal(most_common_publisher, "Electronic Arts")
        assert_equal(most_common_genre, "Action")
        
        assert_equal(top_20.iloc[1].Name, 'Super Mario Bros')
            
        assert_equal(top_20.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
    
        assert_equal(the_median, 0.08)
        
        assert_equal(fifa_data.iloc[0].Platform, 'PS3')
        assert_equal(median_ten_game.iloc[0].Name, 'Dragon Warrior IV')
        

    print("Success!!!")

test()
# Out:
# Success!!!
